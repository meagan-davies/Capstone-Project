# %%
# Load all saved models
models = {
    'v1': load_model('model_v1'),
    'v2': load_model('model_v2'),
    'v3': load_model('model_v3'),
}

# %%
# Performance comparison
fig, axes = plt.subplots(1, 3, figsize=(15, 5))
for i, (name, model) in enumerate(models.items()):
    plot_confusion_matrix(model, ax=axes[i])
    axes[i].set_title(f"Model {name}")

# %%
# Per-class performance over time
dates = ['Dec 2', 'Dec 7', 'Dec 10']
accuracies = load_accuracies_by_date()
plot_learning_curve(dates, accuracies)

# %%
# Create final report
from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred))

# %%
# Export figures for paper
plt.savefig('figures/confusion_matrix.png', dpi=300
